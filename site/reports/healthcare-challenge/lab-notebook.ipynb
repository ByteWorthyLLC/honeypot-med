# %% [markdown]
# # Honeypot Med Healthcare AI Challenge Lab Notebook
#
# Generated by Honeypot Med. No model API calls are required.

# %%
summary = {
  "events": 10,
  "survived": 8,
  "bitten": 2,
  "uncertain": 0,
  "high_risk_events": 2,
  "proven_findings": 3
}
summary

# %% [markdown]
# ## Next experiment
#
# Pick one event, change one variable, rerun `python app.py casebook --input ...`.
